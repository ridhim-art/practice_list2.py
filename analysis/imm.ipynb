# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('data/Canada.xlsx',sheet_name="Canada by Citizenship")

# %%
df
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    NaN         NaN        NaN        NaN        NaN
# 1                    NaN         NaN        NaN        NaN        NaN
# 2                    NaN         NaN        NaN        NaN        NaN
# 3         United Nations         NaN        NaN        NaN        NaN
# 4    Population Division         NaN        NaN        NaN        NaN
# ..                   ...         ...        ...        ...        ...
# 212           Immigrants  Foreigners      Yemen        935       Asia
# 213           Immigrants  Foreigners     Zambia        903     Africa
# 214           Immigrants  Foreigners   Zimbabwe        903     Africa
# 215           Immigrants  Foreigners    Unknown        999      World
# 216           Immigrants        Both      Total        999      World
#
#     Unnamed: 5      Unnamed: 6 Unnamed: 7          Unnamed: 8  Unnamed: 9  \
# 0          NaN             NaN        NaN                 NaN         NaN
# 1          NaN             NaN        NaN                 NaN         NaN
# 2          NaN             NaN        NaN                 NaN         NaN
# 3          NaN             NaN        NaN                 NaN         NaN
# 4          NaN             NaN        NaN                 NaN         NaN
# ..         ...             ...        ...                 ...         ...
# 212        922    Western Asia        902  Developing regions         1.0
# 213        910  Eastern Africa        902  Developing regions        11.0
# 214        910  Eastern Africa        902  Developing regions        72.0
# 215        999           World        999               World     44000.0
# 216        999           World        999               World    143137.0
#
#      ...  Unnamed: 41  Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  \
# 0    ...          NaN          NaN          NaN          NaN          NaN
# 1    ...          NaN          NaN          NaN          NaN          NaN
# 2    ...          NaN          NaN          NaN          NaN          NaN
# 3    ...          NaN          NaN          NaN          NaN          NaN
# 4    ...          NaN          NaN          NaN          NaN          NaN
# ..   ...          ...          ...          ...          ...          ...
# 212  ...        174.0        217.0          NaN          NaN          NaN
# 213  ...         46.0         59.0          NaN          NaN          NaN
# 214  ...        437.0        407.0          NaN          NaN          NaN
# 215  ...       1681.0       1484.0          NaN          NaN          NaN
# 216  ...     257903.0     259021.0          NaN          NaN          NaN
#
#      Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 212          NaN          NaN          NaN          NaN          NaN
# 213          NaN          NaN          NaN          NaN          NaN
# 214          NaN          NaN          NaN          NaN          NaN
# 215          NaN          NaN          NaN          NaN          NaN
# 216          NaN          NaN          NaN          NaN          NaN
#
# [217 rows x 51 columns]

# %%
df=pd.read_excel('data/Canada.xlsx',sheet_name="Canada by Citizenship",skiprows=20, nrows=195)

# %%
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2012  2013  \
# 0         Southern Asia  902  Developing regions    16  ...  2635  2004
# 1       Southern Europe  901   Developed regions     1  ...   620   603
# 2       Northern Africa  902  Developing regions    80  ...  3774  4331
# 3             Polynesia  902  Developing regions     0  ...     0     0
# 4       Southern Europe  901   Developed regions     0  ...     1     1
# ..                  ...  ...                 ...   ...  ...   ...   ...
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1731  2112
# 191     Northern Africa  902  Developing regions     0  ...     0     0
# 192        Western Asia  902  Developing regions     1  ...   174   217
# 193      Eastern Africa  902  Developing regions    11  ...    46    59
# 194      Eastern Africa  902  Developing regions    72  ...   437   407
#
#      Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 190          NaN          NaN          NaN          NaN          NaN
# 191          NaN          NaN          NaN          NaN          NaN
# 192          NaN          NaN          NaN          NaN          NaN
# 193          NaN          NaN          NaN          NaN          NaN
# 194          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# 3            NaN          NaN          NaN
# 4            NaN          NaN          NaN
# ..           ...          ...          ...
# 190          NaN          NaN          NaN
# 191          NaN          NaN          NaN
# 192          NaN          NaN          NaN
# 193          NaN          NaN          NaN
# 194          NaN          NaN          NaN
#
# [195 rows x 51 columns]

# %%
df=pd.read_excel('data/Canada.xlsx',sheet_name="Canada by Citizenship",skiprows=20,nrows=195)
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2012  2013  \
# 0         Southern Asia  902  Developing regions    16  ...  2635  2004
# 1       Southern Europe  901   Developed regions     1  ...   620   603
# 2       Northern Africa  902  Developing regions    80  ...  3774  4331
# 3             Polynesia  902  Developing regions     0  ...     0     0
# 4       Southern Europe  901   Developed regions     0  ...     1     1
# ..                  ...  ...                 ...   ...  ...   ...   ...
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1731  2112
# 191     Northern Africa  902  Developing regions     0  ...     0     0
# 192        Western Asia  902  Developing regions     1  ...   174   217
# 193      Eastern Africa  902  Developing regions    11  ...    46    59
# 194      Eastern Africa  902  Developing regions    72  ...   437   407
#
#      Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 190          NaN          NaN          NaN          NaN          NaN
# 191          NaN          NaN          NaN          NaN          NaN
# 192          NaN          NaN          NaN          NaN          NaN
# 193          NaN          NaN          NaN          NaN          NaN
# 194          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# 3            NaN          NaN          NaN
# 4            NaN          NaN          NaN
# ..           ...          ...          ...
# 190          NaN          NaN          NaN
# 191          NaN          NaN          NaN
# 192          NaN          NaN          NaN
# 193          NaN          NaN          NaN
# 194          NaN          NaN          NaN
#
# [195 rows x 51 columns]

# %%
df.columns
# Out:
# Index([       'Type',    'Coverage',      'OdName',        'AREA',
#           'AreaName',         'REG',     'RegName',         'DEV',
#            'DevName',          1980,          1981,          1982,
#                 1983,          1984,          1985,          1986,
#                 1987,          1988,          1989,          1990,
#                 1991,          1992,          1993,          1994,
#                 1995,          1996,          1997,          1998,
#                 1999,          2000,          2001,          2002,
#                 2003,          2004,          2005,          2006,
#                 2007,          2008,          2009,          2010,
#                 2011,          2012,          2013, 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'],
#       dtype='object')

# %%
cols_to_drop=['Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
       'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50']
df.drop(labels=cols_to_drop,axis=1,inplace=True)

# %%
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2005  2006  2007  \
# 0         Southern Asia  902  Developing regions    16  ...  3436  3009  2652
# 1       Southern Europe  901   Developed regions     1  ...  1223   856   702
# 2       Northern Africa  902  Developing regions    80  ...  3626  4807  3623
# 3             Polynesia  902  Developing regions     0  ...     0     1     0
# 4       Southern Europe  901   Developed regions     0  ...     0     1     1
# ..                  ...  ...                 ...   ...  ...   ...   ...   ...
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1852  3153  2574
# 191     Northern Africa  902  Developing regions     0  ...     0     1     0
# 192        Western Asia  902  Developing regions     1  ...   161   140   122
# 193      Eastern Africa  902  Developing regions    11  ...    91    77    71
# 194      Eastern Africa  902  Developing regions    72  ...   615   454   663
#
#      2008  2009  2010  2011  2012  2013  Unnamed: 43
# 0    2111  1746  1758  2203  2635  2004          NaN
# 1     560   716   561   539   620   603          NaN
# 2    4005  5393  4752  4325  3774  4331          NaN
# 3       0     0     0     0     0     0          NaN
# 4       0     0     0     0     1     1          NaN
# ..    ...   ...   ...   ...   ...   ...          ...
# 190  1784  2171  1942  1723  1731  2112          NaN
# 191     0     0     0     0     0     0          NaN
# 192   133   128   211   160   174   217          NaN
# 193    64    60   102    69    46    59          NaN
# 194   611   508   494   434   437   407          NaN
#
# [195 rows x 44 columns]

# %%
df['Type'].value_counts()
# Out:
# Immigrants    195
# Name: Type, dtype: int64

# %%
df['Coverage'].value_counts()
# Out:
# Foreigners    194
# Citizens        1
# Name: Coverage, dtype: int64

# %%
df['DevName'].value_counts()
# Out:
# Developing regions    147
# Developed regions      48
# Name: DevName, dtype: int64

# %%
df['OdName'].value_counts()
# Out:
# Djibouti                                      1
# Austria                                       1
# China, Macao Special Administrative Region    1
# Republic of Moldova                           1
# Albania                                       1
#                                              ..
# Mexico                                        1
# Antigua and Barbuda                           1
# Hungary                                       1
# Ghana                                         1
# Kiribati                                      1
# Name: OdName, Length: 195, dtype: int64

# %%
df.columns
# Out:
# Index([       'Type',    'Coverage',      'OdName',        'AREA',
#           'AreaName',         'REG',     'RegName',         'DEV',
#            'DevName',          1980,          1981,          1982,
#                 1983,          1984,          1985,          1986,
#                 1987,          1988,          1989,          1990,
#                 1991,          1992,          1993,          1994,
#                 1995,          1996,          1997,          1998,
#                 1999,          2000,          2001,          2002,
#                 2003,          2004,          2005,          2006,
#                 2007,          2008,          2009,          2010,
#                 2011,          2012,          2013, 'Unnamed: 43'],
#       dtype='object')

# %%
df.rename({'OdName':'Country',
          "AreaName":"Continent",
          "RegName":"Region",
          "DevName":"Status"},axis=1,inplace=True)

# %%
df.head()
# Out:
#          Type    Coverage         Country  AREA Continent   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 1  Immigrants  Foreigners         Albania   908    Europe   925
# 2  Immigrants  Foreigners         Algeria   903    Africa   912
# 3  Immigrants  Foreigners  American Samoa   909   Oceania   957
# 4  Immigrants  Foreigners         Andorra   908    Europe   925
#
#             Region  DEV              Status  1980  ...  2005  2006  2007  \
# 0    Southern Asia  902  Developing regions    16  ...  3436  3009  2652
# 1  Southern Europe  901   Developed regions     1  ...  1223   856   702
# 2  Northern Africa  902  Developing regions    80  ...  3626  4807  3623
# 3        Polynesia  902  Developing regions     0  ...     0     1     0
# 4  Southern Europe  901   Developed regions     0  ...     0     1     1
#
#    2008  2009  2010  2011  2012  2013  Unnamed: 43
# 0  2111  1746  1758  2203  2635  2004          NaN
# 1   560   716   561   539   620   603          NaN
# 2  4005  5393  4752  4325  3774  4331          NaN
# 3     0     0     0     0     0     0          NaN
# 4     0     0     0     0     1     1          NaN
#
# [5 rows x 44 columns]

# %%
df.set_index('Country',inplace=True)

# %%
df.head()[2013].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
df.columns
# Out:
# Index([       'Type',    'Coverage',        'AREA',   'Continent',
#                'REG',      'Region',         'DEV',      'Status',
#                 1980,          1981,          1982,          1983,
#                 1984,          1985,          1986,          1987,
#                 1988,          1989,          1990,          1991,
#                 1992,          1993,          1994,          1995,
#                 1996,          1997,          1998,          1999,
#                 2000,          2001,          2002,          2003,
#                 2004,          2005,          2006,          2007,
#                 2008,          2009,          2010,          2011,
#                 2012,          2013, 'Unnamed: 43'],
#       dtype='object')

# %%
cols=[ 'Type',    'Coverage',        'AREA',   
               'REG',       'DEV']
df.drop(cols,axis=1,inplace=True)
df.head()
# Out:
#                Continent           Region              Status  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
#                 2009  2010  2011  2012  2013  Unnamed: 43
# Country
# Afghanistan     1746  1758  2203  2635  2004          NaN
# Albania          716   561   539   620   603          NaN
# Algeria         5393  4752  4325  3774  4331          NaN
# American Samoa     0     0     0     0     0          NaN
# Andorra            0     0     0     1     1          NaN
#
# [5 rows x 38 columns]

# %%
df.groupby('Continent')[1985,2013].sum().plot(kind='pie',subplots=True,figsize=(16,9),title='continent wise immigration in 2013',autopct='%%3f')
plt.show()
# Out:
# <ipython-input-21-ff5f497cb8fb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Continent')[1985,2013].sum().plot(kind='pie',subplots=True,figsize=(16,9),title='continent wise immigration in 2013',autopct='%%3f')

# %%
years=list(range(1980,2014))
df_france=df.loc[['France'],years]
df_france.T.describe()
# Out:
# Country       France
# count      34.000000
# mean     3208.558824
# std      1295.448026
# min      1169.000000
# 25%      2187.500000
# 50%      3337.500000
# 75%      4060.500000
# max      6280.000000

# %%
df_france.T.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df_fg=df.loc[['France','Germany'],years].T
df_fg
# Out:
# Country  France  Germany
# 1980       1729     1626
# 1981       2027     1977
# 1982       2219     3062
# 1983       1490     2376
# 1984       1169     1610
# 1985       1177     1441
# 1986       1298     1233
# 1987       1658     1704
# 1988       2038     1482
# 1989       2332     1706
# 1990       2177     1273
# 1991       2911     1273
# 1992       3487     1181
# 1993       3709     1488
# 1994       2759     1255
# 1995       3332     1553
# 1996       2623     1686
# 1997       2473     1397
# 1998       3214     1363
# 1999       3343     1717
# 2000       3765     1703
# 2001       3806     1456
# 2002       3463     1375
# 2003       3568     1865
# 2004       4391     2020
# 2005       4429     2226
# 2006       4002     2767
# 2007       4290     2449
# 2008       4532     3833
# 2009       5051     3887
# 2010       4646     2956
# 2011       4080     2053
# 2012       6280     1702
# 2013       5623     1217

# %%
df_fg.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.columns.tolist()
# Out:
# ['Continent',
#  'Region',
#  'Status',
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  'Unnamed: 43']

# %%
df['Total'] = df[years].sum(axis=1)
df
# Out:
#                Continent              Region              Status  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
#                 1982  1983  1984  1985  1986  ...  2006  2007  2008  2009  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3009  2652  2111  1746
# Albania            0     0     0     0     1  ...   856   702   560   716
# Algeria           71    69    63    44    69  ...  4807  3623  4005  5393
# American Samoa     0     0     0     0     0  ...     1     0     0     0
# Andorra            0     0     0     0     2  ...     1     1     0     0
# ...              ...   ...   ...   ...   ...  ...   ...   ...   ...   ...
# Viet Nam        2162  3404  7583  5907  2741  ...  3153  2574  1784  2171
# Western Sahara     0     0     0     0     0  ...     1     0     0     0
# Yemen              1     6     0    18     7  ...   140   122   133   128
# Zambia            11     7    16     9    15  ...    77    71    64    60
# Zimbabwe         102    44    32    29    43  ...   454   663   611   508
#
#                 2010  2011  2012  2013  Unnamed: 43  Total
# Country
# Afghanistan     1758  2203  2635  2004          NaN  58639
# Albania          561   539   620   603          NaN  15699
# Algeria         4752  4325  3774  4331          NaN  69439
# American Samoa     0     0     0     0          NaN      6
# Andorra            0     0     1     1          NaN     15
# ...              ...   ...   ...   ...          ...    ...
# Viet Nam        1942  1723  1731  2112          NaN  97146
# Western Sahara     0     0     0     0          NaN      2
# Yemen            211   160   174   217          NaN   2985
# Zambia           102    69    46    59          NaN   1677
# Zimbabwe         494   434   437   407          NaN   8598
#
# [195 rows x 39 columns]

# %%
import seaborn as sns

# %%
df.sort_values(by='Total',inplace=True,ascending=False)

# %%
df
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
# ...                                                      ...
# San Marino                                            Europe
# New Caledonia                                        Oceania
# Marshall Islands                                     Oceania
# Western Sahara                                        Africa
# Palau                                                Oceania
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
# ...                                                                ...
# San Marino                                             Southern Europe
# New Caledonia                                                Melanesia
# Marshall Islands                                            Micronesia
# Western Sahara                                         Northern Africa
# Palau                                                       Micronesia
#
#                                                                 Status   1980  \
# Country
# India                                               Developing regions   8880
# China                                               Developing regions   5123
# United Kingdom of Great Britain and Northern Ir...   Developed regions  22045
# Philippines                                         Developing regions   6051
# Pakistan                                            Developing regions    978
# ...                                                                ...    ...
# San Marino                                           Developed regions      1
# New Caledonia                                       Developing regions      0
# Marshall Islands                                    Developing regions      0
# Western Sahara                                      Developing regions      0
# Palau                                               Developing regions      0
#
#                                                      1981   1982   1983  \
# Country
# India                                                8670   8147   7338
# China                                                6682   3308   1863
# United Kingdom of Great Britain and Northern Ir...  24796  20620  10015
# Philippines                                          5921   5249   4562
# Pakistan                                              972   1201    900
# ...                                                   ...    ...    ...
# San Marino                                              0      0      0
# New Caledonia                                           0      0      0
# Marshall Islands                                        0      0      0
# Western Sahara                                          0      0      0
# Palau                                                   0      0      0
#
#                                                      1984  1985  1986  ...  \
# Country                                                                ...
# India                                                5704  4211  7150  ...
# China                                                1527  1816  1960  ...
# United Kingdom of Great Britain and Northern Ir...  10170  9564  9470  ...
# Philippines                                          3801  3150  4166  ...
# Pakistan                                              668   514   691  ...
# ...                                                   ...   ...   ...  ...
# San Marino                                              0     0     1  ...
# New Caledonia                                           0     0     0  ...
# Marshall Islands                                        0     0     0  ...
# Western Sahara                                          0     0     0  ...
# Palau                                                   0     0     0  ...
#
#                                                      2006   2007   2008  \
# Country
# India                                               33848  28742  28261
# China                                               33518  27642  30037
# United Kingdom of Great Britain and Northern Ir...   7140   8216   8979
# Philippines                                         18400  19837  24887
# Pakistan                                            13127  10124   8994
# ...                                                   ...    ...    ...
# San Marino                                              0      0      0
# New Caledonia                                           0      0      1
# Marshall Islands                                        0      2      0
# Western Sahara                                          1      0      0
# Palau                                                   0      1      0
#
#                                                      2009   2010   2011  \
# Country
# India                                               29456  34235  27509
# China                                               29622  30391  28502
# United Kingdom of Great Britain and Northern Ir...   8876   8724   6204
# Philippines                                         28573  38617  36765
# Pakistan                                             7217   6811   7468
# ...                                                   ...    ...    ...
# San Marino                                              0      1      0
# New Caledonia                                           0      0      0
# Marshall Islands                                        0      0      0
# Western Sahara                                          0      0      0
# Palau                                                   0      0      0
#
#                                                      2012   2013  Unnamed: 43  \
# Country
# India                                               30933  33087          NaN
# China                                               33024  34129          NaN
# United Kingdom of Great Britain and Northern Ir...   6195   5827          NaN
# Philippines                                         34315  29544          NaN
# Pakistan                                            11227  12603          NaN
# ...                                                   ...    ...          ...
# San Marino                                              0      0          NaN
# New Caledonia                                           0      2          NaN
# Marshall Islands                                        0      0          NaN
# Western Sahara                                          0      0          NaN
# Palau                                                   0      0          NaN
#
#                                                      Total
# Country
# India                                               691904
# China                                               659962
# United Kingdom of Great Britain and Northern Ir...  551500
# Philippines                                         511391
# Pakistan                                            241600
# ...                                                    ...
# San Marino                                               5
# New Caledonia                                            5
# Marshall Islands                                         2
# Western Sahara                                           2
# Palau                                                    1
#
# [195 rows x 39 columns]

# %%
df.head()[years].T.plot(kind='area',stacked=False,alpha=.3,figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
df.head()[years].T.plot(kind='hist',alpha=.3,figsize=(5,20),subplots=True)
plt.show()

# %%
df.plot.hexbin?
# Out:
# Signature:
# df.plot.hexbin(
#     x,
#     y,
#     C=None,
#     reduce_C_function=None,
#     gridsize=None,
#     **kwargs,
# )
# Docstring:
# Generate a hexagonal binning plot.
#
# Generate a hexagonal binning plot of `x` versus `y`. If `C` is `None`
# (the default), this is a histogram of the number of occurrences
# of the observations at ``(x[i], y[i])``.
#
# If `C` is specified, specifies values at given coordinates
# ``(x[i], y[i])``. These values are accumulated for each hexagonal
# bin and then reduced according to `reduce_C_function`,
# having as default the NumPy's mean function (:meth:`numpy.mean`).
# (If `C` is specified, it must also be a 1-D sequence
# of the same length as `x` and `y`, or a column label.)
#
# Parameters
# ----------
# x : int or str
#     The column label or position for x points.
# y : int or str
#     The column label or position for y points.
# C : int or str, optional
#     The column label or position for the value of `(x, y)` point.
# reduce_C_function : callable, default `np.mean`
#     Function of one argument that reduces all the values in a bin to
#     a single number (e.g. `np.mean`, `np.max`, `np.sum`, `np.std`).
# gridsize : int or tuple of (int, int), default 100
#     The number of hexagons in the x-direction.
#     The corresponding number of hexagons in the y-direction is
#     chosen in a way that the hexagons are approximately regular.
#     Alternatively, gridsize can be a tuple with two elements
#     specifying the number of hexagons in the x-direction and the
#     y-direction.
# **kwargs
#     Additional keyword arguments are documented in
#     :meth:`DataFrame.plot`.
#
# Returns
# -------
# matplotlib.AxesSubplot
#     The matplotlib ``Axes`` on which the hexbin is plotted.
#
# See Also
# --------
# DataFrame.plot : Make plots of a DataFrame.
# matplotlib.pyplot.hexbin : Hexagonal binning plot using matplotlib,
#     the matplotlib function that is used under the hood.
#
# Examples
# --------
# The following examples are generated with random data from
# a normal distribution.
#
# .. plot::
#     :context: close-figs
#
#     >>> n = 10000
#     >>> df = pd.DataFrame({'x': np.random.randn(n),
#     ...                    'y': np.random.randn(n)})
#     >>> ax = df.plot.hexbin(x='x', y='y', gridsize=20)
#
# The next example uses `C` and `np.sum` as `reduce_C_function`.
# Note that `'observations'` values ranges from 1 to 5 but the result
# plot shows values up to more than 25. This is because of the
# `reduce_C_function`.
#
# .. plot::
#     :context: close-figs
#
#     >>> n = 500
#     >>> df = pd.DataFrame({
#     ...     'coord_x': np.random.uniform(-3, 3, size=n),
#     ...     'coord_y': np.random.uniform(30, 50, size=n),
#     ...     'observations': np.random.randint(1,5, size=n)
#     ...     })
#     >>> ax = df.plot.hexbin(x='coord_x',
#     ...                     y='coord_y',
#     ...                     C='observations',
#     ...                     reduce_C_function=np.sum,
#     ...                     gridsize=10,
#     ...                     cmap="viridis")
# File:      c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages\pandas\plotting\_core.py
# Type:      method
