# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/weather.csv',parse_dates=['Date/Time'],dayfirst=True)
df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df['Temp (C)']
# Out:
# 0      -1.8
# 1      -1.8
# 2      -1.8
# 3      -1.5
# 4      -1.5
#        ...
# 8779    0.1
# 8780    0.2
# 8781   -0.5
# 8782   -0.2
# 8783    0.0
# Name: Temp (C), Length: 8784, dtype: float64

# %%
df['Temp (C)'].tolist()
# Out:
# [-1.8,
#  -1.8,
#  -1.8,
#  -1.5,
#  -1.5,
#  -1.4,
#  -1.5,
#  -1.4,
#  -1.4,
#  -1.3,
#  -1.0,
#  -0.5,
#  -0.2,
#  0.2,
#  0.8,
#  1.8,
#  2.6,
#  3.0,
#  3.8,
#  3.1,
#  3.2,
#  4.0,
#  4.4,
#  5.3,
#  5.2,
#  4.6,
#  3.9,
#  3.7,
#  2.9,
#  2.6,
#  2.3,
#  2.0,
#  1.9,
#  1.8,
#  1.5,
#  2.2,
#  1.7,
#  1.1,
#  1.1,
#  0.0,
#  -0.7,
#  -2.1,
#  -4.1,
#  -4.8,
#  -5.6,
#  -5.8,
#  -7.0,
#  -7.4,
#  -9.0,
#  -9.7,
#  -10.5,
#  -11.3,
#  -12.6,
#  -12.9,
#  -13.3,
#  -14.0,
#  -14.8,
#  -15.0,
#  -15.3,
#  -14.9,
#  -14.9,
#  -15.1,
#  -14.9,
#  -14.8,
#  -15.3,
#  -15.8,
#  -16.3,
#  -16.9,
#  -17.3,
#  -17.0,
#  -17.1,
#  -17.3,
#  -17.5,
#  -17.9,
#  -18.1,
#  -18.5,
#  -18.5,
#  -18.6,
#  -18.5,
#  -18.2,
#  -17.8,
#  -16.8,
#  -15.2,
#  -14.2,
#  -13.7,
#  -12.4,
#  -11.3,
#  -10.2,
#  -9.4,
#  -8.9,
#  -8.9,
#  -8.4,
#  -7.8,
#  -7.6,
#  -9.5,
#  -9.6,
#  -8.8,
#  -7.5,
#  -5.4,
#  -5.0,
#  -4.1,
#  -7.0,
#  -8.2,
#  -7.1,
#  -6.1,
#  -6.6,
#  -6.0,
#  -5.6,
#  -4.7,
# ...

# %%
df['Rel Hum (%)']
# Out:
# 0       86
# 1       87
# 2       89
# 3       88
# 4       88
#         ..
# 8779    81
# 8780    83
# 8781    93
# 8782    89
# 8783    86
# Name: Rel Hum (%), Length: 8784, dtype: int64

# %%
df['Dew Point Temp (C)'].head()
# Out:
# 0   -3.9
# 1   -3.7
# 2   -3.4
# 3   -3.2
# 4   -3.3
# Name: Dew Point Temp (C), dtype: float64

# %%
df[['Temp (C)','Visibility (km)','Weather']]
# Out:
#       Temp (C)  Visibility (km)               Weather
# 0         -1.8              8.0                   Fog
# 1         -1.8              8.0                   Fog
# 2         -1.8              4.0  Freezing Drizzle,Fog
# 3         -1.5              4.0  Freezing Drizzle,Fog
# 4         -1.5              4.8                   Fog
# ...        ...              ...                   ...
# 8779       0.1              9.7                  Snow
# 8780       0.2              9.7                  Snow
# 8781      -0.5              4.8                  Snow
# 8782      -0.2              9.7                  Snow
# 8783       0.0             11.3                  Snow
#
# [8784 rows x 3 columns]

# %%
df['Temp (C)'].max()
# Out:
# 33.0

# %%
df['Temp (C)'].min()
# Out:
# -23.3

# %%
df['Temp (C)'].std()
# Out:
# 11.687882769691276

# %%
df['Temp (C)'].sum()
# Out:
# 77282.90000000001

# %%
df['Temp (C)'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Temp (C)'].plot(figsize=(25,7))
# Out:
# <AxesSubplot:>

# %%
df['Temp (C)'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
##row selection
df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df.head(19)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6  2012-01-01 06:00:00      -1.5                -3.1           89
# 7  2012-01-01 07:00:00      -1.4                -3.6           85
# 8  2012-01-01 08:00:00      -1.4                -3.6           85
# 9  2012-01-01 09:00:00      -1.3                -3.1           88
# 10 2012-01-01 10:00:00      -1.0                -2.3           91
# 11 2012-01-01 11:00:00      -0.5                -2.1           89
# 12 2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
df['Temp (C)'].head()
# Out:
# 0   -1.8
# 1   -1.8
# 2   -1.8
# 3   -1.5
# 4   -1.5
# Name: Temp (C), dtype: float64

# %%
df.iloc[0]
# Out:
# Date/Time             2012-01-01 00:00:00
# Temp (C)                             -1.8
# Dew Point Temp (C)                   -3.9
# Rel Hum (%)                            86
# Wind Spd (km/h)                         4
# Visibility (km)                       8.0
# Stn Press (kPa)                    101.24
# Weather                               Fog
# Name: 0, dtype: object

# %%
df.iloc[2322]
# Out:
# Date/Time             2012-04-06 18:00:00
# Temp (C)                              7.3
# Dew Point Temp (C)                  -11.6
# Rel Hum (%)                            25
# Wind Spd (km/h)                        19
# Visibility (km)                      25.0
# Stn Press (kPa)                    101.16
# Weather                     Mostly Cloudy
# Name: 2322, dtype: object
